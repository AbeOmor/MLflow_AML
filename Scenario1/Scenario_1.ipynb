# %% [markdown]
# ## Scenario 1: Local to Remote with MLFlow (Tracking)

# %% [markdown]
# 1)	User trains locally using MLFlow using MLFlow logging / autologging
#
# 2)	Move to AML by setting the tracking URI in the backend (not in my training code), packaging as a project and using the AzureML CLIv2 or MLFlow CLI. The user doesn’t have to change their training or scoring code.
#
#     a.	Help users set MLFLOW_TRACKING_URI via CLI (can we get TRACKING URI from the CLI?)
#
#         i.	Use: az ml workspace show | grep "mlflow_tracking_uri"
#
#     b.	User should be able to run same code
#
#         i.	python train.py
#
#     c.	The user can run that same training script locally and still have everything tracked in AML without updating code
#
# 3)	All AML parameters, metrics, models and logged artifacts should show up in AML run history
#
# **NOTE** This only works if the user has set an experiment in their code, if not it break. We need to be able to set a default experiment for the user with now experiment set.

# %% [markdown]
# Doc: https://microsoft-my.sharepoint.com/:w:/p/osomorog/Ed7l1SLKac9Irz_PY-XnXaQB90-WeAosazcQOT24PRd3-g?e=hKS09V

# %% [markdown]
# ## User trains locally using MLFlow using MLFlow logging / autologging

# %%
# Copyright (c) Microsoft. All rights reserved.
# Licensed under the MIT license.

import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import mlflow
import mlflow.sklearn

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

with mlflow.start_run():
    X, y = load_diabetes(return_X_y=True)
    columns = ['age', 'gender', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    data = {
        "train": {"X": X_train, "y": y_train},
        "test": {"X": X_test, "y": y_test}}

    mlflow.log_metric("Training samples", len(data['train']['X']))
    mlflow.log_metric("Test samples", len(data['test']['X']))

    # Log the algorithm parameter alpha to the run
    mlflow.log_metric('alpha', 0.03)
    # Create, fit, and test the scikit-learn Ridge regression model
    regression_model = Ridge(alpha=0.03)
    regression_model.fit(data['train']['X'], data['train']['y'])
    preds = regression_model.predict(data['test']['X'])

    # Log mean squared error
    print('Mean Squared Error is', mean_squared_error(data['test']['y'], preds))
    mlflow.log_metric('mse', mean_squared_error(data['test']['y'], preds))

    # Save the model to the outputs directory for capture
    mlflow.sklearn.log_model(regression_model, "model")

    # Plot actuals vs predictions and save the plot within the run
    fig = plt.figure(1)
    idx = np.argsort(data['test']['y'])
    plt.plot(data['test']['y'][idx], preds[idx])
    fig.savefig("actuals_vs_predictions.png")
    mlflow.log_artifact("actuals_vs_predictions.png")
# Out:
# Mean Squared Error is 3424.900315896017

# %% [markdown]
# Look for the **/mlruns** folder in your current directory to find the run details

# %% [markdown]
# ## Move to AML by setting the tracking URI in the backend (not in my training code), and using MLFlow CLI.

# %% [markdown]
# **NOTE:** The Compute instance team will be added in Tracking_URI to every COmpute Instance in the future

# %%
# !az extension add -n ml -y
# Out:
# Extension 'ml' is already installed.

# %%
# !az login
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code AZGDYBZ96 to authenticate.
# The following tenants don't contain accessible subscriptions. Use 'az login --allow-no-subscriptions' to have tenant level access.
# b1c14d5c-3625-45b3-a430-9552373a0c2f 'SAS'
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "d6f18478-178f-450d-8f3e-a891b4d83dd0",
#     "id": "59ea72cc-1f3e-4d29-bd60-242d81b57b05",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Visual Studio Enterprise Subscription",
#     "state": "Enabled",
#     "tenantId": "d6f18478-178f-450d-8f3e-a891b4d83dd0",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "316a14b3-f94a-4267-a76a-497e589ef0a8",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Ranker training",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8c4b5b03-3b24-4ed0-91f5-a703cd91b412",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_C&E_Azure_AzureEngineeringSystems_100200",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "dad45786-32e5-4ef3-b90e-8e0838fbadb6",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AnE.ExP.Production",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "6560575d-fa06-4e7d-95fb-f962e74efd7a",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ML Lifecycle PM",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "20d3c9e4-625d-45e1-ac8a-def90d3c4a88",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "DLTS - Training",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "7a7b5559-58af-401a-b543-61b7321a97ea",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Epic-Edge-ES-GitCache-Prod",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "bac420ed-c6fc-4a05-8ac1-8c0c52da1d6e",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "IDEAs MS Reporting",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "7fd08dcc-a653-4b0f-8f8c-4dac889fdda4",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Code generate Test and Infra",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "f92fab0a-38b9-44ed-b800-2ed55fa1b9d9",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Kensho",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "48bbc269-ce89-4f6f-9a12-c6f91fcb772d",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "aims",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "5cd8e2ec-4ce2-410c-9817-7f93ec84541e",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_C&E_Azure_R&D Data-Exec Office_100540",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "c3547baf-332f-4d8f-96bd-0659b39c7a59",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "MSAI Search Research",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "407ff5d7-0113-4c5c-8534-f5cfb09298f5",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "msteams.nonprod.pub.msft.msts",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "588845a8-a4a7-4ab1-83a1-1388452e8c0c",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Saidi Dev and Test Subscription",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4faaaf21-663f-4391-96fd-47197c630979",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna Build Tests",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "1aefdc5e-3a7c-4d71-a9f9-f5d3b03be19a",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AML FeatureStoreEUAP",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "3d75862d-3a43-450d-8046-895947d5abfa",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Speech Infrastructure",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "3905431d-c062-4c17-8fd9-c51f89f334c4",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Pytorch Build",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "2cd190bb-b42a-477c-b1bb-2f20932d8dc5",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Deep Learning Group",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "59575035-46ba-4b83-8025-0cb076c7c097",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "STCA-Segment Intelligence",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4aaa645c-5ae2-4ae9-a17a-84b9023bc56a",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Azure ML Team Testing",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4bf6b28a-452b-4af4-8080-8a196ee0ca4b",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AriaOdin",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "482e1993-01d4-4b16-bff4-1866929176a1",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Epic-Edge-ES-MergeResolver",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "26596251-f2f3-4e31-8a1b-f0754e32ad73",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Epic-Edge-ES-SrcPub-Prod",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "95a911b6-47f7-4a8b-be9b-c1c2bf56579b",
#     "isDefault": true,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Vienna PM 2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4e84ed7c-8068-4e31-87be-d595344efd21",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AML EPR",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "58f8824d-32b0-4825-9825-02fa6a801546",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "BigDataPMInternal",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "56dcf710-f955-442e-8ac2-3b90ab65dea1",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "33e01921-4d64-4f8c-a055-5bdaffd5e33d"
#       }
#     ],
#     "name": "Data Studio Public Telemetry",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e01de573-132a-42ac-9ee2-f9dea9dd2717",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_WDG_Core_BnB_100292",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "08cbec86-0544-47f0-a280-a6a76a165c0f",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_AIR_BingExp_AWE_100023",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4062f5e8-5e2b-447f-a06f-62b65b731b0d",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Cosmos_AIR_BingExp_Ranking and Intent_100043",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "f9b96b36-1f5e-4021-8959-51527e26e6d3",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "CS-Platform-Dev-01",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ee85ed72-2b26-48f6-a0e8-cb5bcf98fbd9",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Subscription-1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "102a16c3-37d3-48a8-9237-4c9b1e8e80e0",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AutoML",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4115b323-4aac-47f4-bb13-22af265ed58b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "ES-ESP-AS-vPack-Nonprod",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "83a9a25f-d922-437f-bc5b-79f3b6827513",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "ES-ESP-AS-vPack-Prod",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "f12aca23-53d1-4587-9e3e-740318475a18",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna Telemetry",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "9ec1d932-0f3f-486c-acc6-e7d78b358f9b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "TScience",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8c2c7b23-848d-40fe-b817-690d79ad9dfd",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Babylon_Partner_Sandbox",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "29de2cfc-f00a-43bb-bdc8-3108795bd282",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "MSFT-Modern Device-Modern Mgmt-Imaging00",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "7afc2d66-d5b4-4e84-970b-a782e3e4cc46",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "CLOUDBUILD-ANYBUILD-POC-01",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "7d411d23-59e5-4e2e-8566-4f59de4544f2",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "ER: CE Security Service Operation Center",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "0368444d-756e-4ca6-9ecd-e964248c227a",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AnyBuild-InternalProdClusters",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "cb9eb375-570a-4e75-b83a-77dd942bee9f",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "PPP_ACBB_ATS_Geneva_NonProd",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "009d0e9f-a42a-470e-b315-82496a88cf0f",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Weather and Finance INT",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "3c69a94e-4f48-4b8b-8bdf-aff82fa0ac9c",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Microsoft Services Disaster Response",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "a1920ebd-59b7-4f19-af9f-5e80599e88e4",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Babel",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8cff5d56-95fb-4a74-ab9d-079edb45313e",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "cdc5aeea-15c5-4db6-b079-fcadd2505dc2"
#       }
#     ],
#     "name": "Skype-NetEM-STAGING",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8a6e61f6-4dae-4242-b835-83b8aafcbbed",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "DESP-APT-MTB-Prod",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "eec2de82-6ab2-4a84-ae5f-57e9a10bf661",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ServicesPortfolio MCS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d21a0e9f-5e29-4b39-8ba5-0e189bc5fe2d",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Edge DevTools Client",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "02d68940-61e6-42d0-81d1-8396b7451114",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Linux Microservices PROD",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ae71ef11-a03f-4b4f-a0e6-ef144727c711",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Bing MM Measurement",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8ae1955e-f748-4273-a507-10159ba940f9",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "SPO-CyrusB",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "eef8b6d5-94da-4b36-9327-a662f2674efb",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AISC-EngSys-01",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b2a328a7-ffff-4c09-b643-a4758cf170bc",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AISC-DEV-02",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "56207a5d-4746-4a2d-9f7f-c5ac77a5ddfd",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Traffic manager PPE",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ca38bc19-cf50-48e2-bbe6-8c35b40212d8",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Maps Mining Azure",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "85b3dbca-5974-4067-9669-67a141095a76",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "027fe226-784c-4798-a157-5e0e7893424d"
#       }
#     ],
#     "name": "Terraform Testing on Azure with TTL = 2 Days",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "35f16a99-532a-4a47-9e93-00305f6c40f2",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Data Wrangling development",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d511f82f-71ba-49a4-8233-d7be8a3650f4",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "bai-eastus-dogfood-pool-1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "2ab32971-d92b-4038-a56c-4315e4a8deef",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - WestEurope",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b287e980-0165-47df-b897-347940f8f528",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - CanadaCentral",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "74eccef0-4b8d-4f83-b5f9-fa100d155b22",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AML V1 Build 1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "dd21e9f4-d52f-406f-ab5e-d164e7d7dc65",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Azure ML Training - Runner Resource Creation",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "a5fe3bc5-98f0-4c84-affc-a589f54d9b23",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna Personal 2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d08f1142-742d-4251-9908-8a8d2dc7b865",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - CanadaCentral",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "01986d28-6a39-40f4-bb0f-c9b02f8f4131",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - EastUS2EUAP",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "96aede12-2f73-41cb-b983-6d11a904839b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna R&D - RaoS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "a4cb9ffb-8007-4e46-9a86-60c7a1cde38c",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna – Metrics Runner Public",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ad07bff6-55a5-44d9-9417-f25939941d00",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - NorthEurope",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8eedaad9-b9a9-4c77-873f-ae9b9621a564",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "mir-fd-main-westus2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4f455bd0-f95a-4b7d-8d08-078611508e0b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AML V1 Build 2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "f700e635-93e3-47f6-bcce-40c2041ee167",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - CentralUSEUAP",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "7ad5283f-8555-4f0b-9543-a78cc07bf0e5",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - WestUS2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "663724c3-071d-409b-bf3b-356add9b6b70",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna R&D - BuckH",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4e7b3094-d7f1-4973-8734-e82a24f1590e",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AML V1 INT 2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b0d50d34-4247-4cae-871a-6b1799907b8d",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna Ephemeral",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "c1e7126e-e06d-48ac-bde2-5707af720c40",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna - Runner Resource Creation - Japan West",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "22b80983-c31e-465e-a272-06f51fde6c98",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - WestUS3",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "a02ce7fd-1f09-4cd2-855d-49b67aef9c20",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - WestUS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "6ea83dee-1056-4dd2-b926-8118432808a3",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - EastAsia",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "0e3f75c8-66e9-439d-b737-e05527eb1fd9",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna - Runner Resource Creation - Jio India West",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "7421b5fd-cf60-4260-b2a2-dbb76e98458b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna Test-Managed Cluster",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e5388881-739a-49db-982b-6a4b412179ed",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - CentralUS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "15a00053-83f6-4fd3-ac85-fddefa2cfb6d",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - Korea Central",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b95ddc94-1dc3-4916-bdc8-ac13cd8e2eaf",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - AustraliaEast",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "589c7ae9-223e-45e3-a191-98433e0821a9",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna INT",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "04abf173-6a6e-46ba-9edc-4c3cd4c90a62",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - SouthEastAsia",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "eb1a770b-444b-4e41-8655-9f27db63f22f",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna - Runner Resource Creation - WestUS3",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ba709ca5-1a2c-479c-a1cb-6e0346b81bf1",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "sing-int-eastus-prod-pool-01",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "1544855c-d3b7-4517-b765-a61123dffb63",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna - Runner Resource Creation - UKWest",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "72c03bf3-4e69-41af-9532-dfcdc3eefef4",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna R&D - AzureML Intelligence - vaski",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d3504e6e-7936-459c-b215-00e69750b969",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - SouthEastAsia",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "360e1686-f6e9-4886-b64e-e7ed463af573",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - SouthAfricaNorth",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e062a0e0-9809-416f-b638-431baf0807d6",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "mir-fd-dev-westus2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "f8ac18dc-d246-4e66-a49c-09779efe2437",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - JapanEast",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "a5a8fe77-9cf5-46ce-abb7-74521ae46ec4",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - Central India",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "26e3d2a9-1661-44ec-8da9-cad715985a9d",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - AustraliaEast",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "10a1cf3f-9a29-4c5d-aef4-0f6a234190af",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AML V1 INT 1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "74559077-e6bf-4919-a785-da349a31880b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - BrazilSouth",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "2a79b87a-9981-49cd-b73d-16ecd966116a",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna - Runner Resource Creation - AustraliaSoutheast",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "30fd7778-380c-4815-a1aa-dbd7dcd16662",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - KoreaCentral",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "f4d30ee4-1879-430a-b465-e30540018493",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - SouthCentralUS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d579d006-2ffc-4e55-b05a-b24a40fe3c10",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - Brazil South",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "0ae0f834-a94a-481a-b304-dcc9a1e050cd",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - WestUS2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "2d48d175-17b3-479d-91ca-775f9982190d",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna R&D - LanTa",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "76394156-984f-49c8-9827-3d4434fa92a1",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - UKSouth",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "5bdb7cc7-fa12-4f26-a33d-1a2ea0bb7594",
#     "isDefault": false,
# ...
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - France Central",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ffc5a3ec-eee4-4d2b-936f-d1eb5ae388ae",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - CentralUS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4f26493f-21d2-4726-92ea-1ddd550b1d27",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna R&D - KRaman",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "02af6913-ee79-441b-a232-0d3d48956992",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - NorthEurope",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "1acf6fa9-eabe-4d20-b07d-e7eb0d8e631a",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - SouthCentralUS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "75299cf4-97f0-4b4a-8229-819ec1befc21",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - EastUS2EUAP",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "3259880c-4cb2-4ba9-ae23-bcc4b4370193",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - JapanWest",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "09c10678-1633-4767-9569-919c9c354111",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - EastAsia",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ce05db63-cd45-4792-ad2b-f2318a7fe1c6",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna - Runner Resource Creation - WestCentralUS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4f702c02-4b6d-4f1b-a1c4-11d7ae3f8aac",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - EastUS2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "2e7459c4-092c-4905-a8d8-83048632b4ae",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - WestEurope",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "42737d42-7a24-4ceb-91d1-9d261083c0ad",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna - Runner Resource Creation - Japan East",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "79a1ba0c-35bb-436b-bff2-3074d5ff1f89",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna R&D - RogerYu",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "f702b78b-b384-4ddd-9ce1-0d1a1be5b80c",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - NorthCentralUS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ad203158-bc5d-4e72-b764-2607833a71dc",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna Build",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8b5789cd-8107-4765-ae2c-82a3a9289b3a",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Project Vienna – AutoML Runner Public",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "2fd34b77-86b4-48f8-98b1-5ff875a8455e",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "InferenceV2 - Runner Resource Creation - UKSouth",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "13e50845-67bc-4ac5-94db-48d493a6d9e8",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna Stress",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e9b2ec51-5c94-4fa8-809a-dc1e695e4896",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AML V1 Personal 2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8f338f6e-4fce-44ae-969c-fc7d8fda030e",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna RP Tests",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d128f140-94e6-4175-87a7-954b9d27db16",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AML V1 Personal 1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "0ee78edb-a0ad-456c-a0a2-901bf542c102",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ADF Test sub - App Model V2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4bbecc02-f2c3-402a-8e01-1dfb1ffef499",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Azure Portal Telemetry Reporting",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "cd0fa82d-b6b6-4361-b002-050c32f71353",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Falcon Dev Cluster",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d03b04c7-d1d4-467b-aaaa-87b6fcb38b38",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "VSEng Shared",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "26b9b438-7fe8-482f-b732-ea99c70f2abb",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "ddverify",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8bc2f89b-c4f6-4559-ad6a-4f2cfa6ccc49",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "VSEng MadDog-RPS Telemetry",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "eb87f285-893a-4f0f-8c55-7b4f67b1d097",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Dart Eng Alpha",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "58706c15-d8a1-4397-af3c-e1ebf1cbebe5",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "RPS-cloud-common-2",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "52a442a2-31e9-42f9-8e3e-4b27dbf82673",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Core-ES-WorkManagement",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "60582a10-b9fd-49f1-a546-c4194134bba8",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "DataIntegration Devlopment",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "15ae9cb6-95c1-483d-a0e3-b1a1a3b06324",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AzureML Nursery",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "65a1016d-0f67-45d2-b838-b8f373d6d52e",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ML-docs",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "92c76a2f-0e1c-4216-b65e-abf7a3f34c1e",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Operationalization Subscription",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8b3b8a60-1dd0-4824-8770-2ed6a55d8e27",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "A365 Workspace Dev",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "764d6065-e422-4d31-aa82-974cbb48c8b9",
#     "id": "86463f0f-881a-4125-8ced-67b3aceada0f",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Visual Studio Enterprise Subscription",
#     "state": "Enabled",
#     "tenantId": "764d6065-e422-4d31-aa82-974cbb48c8b9",
#     "user": {
#       "name": "osomorog@microsoft.com",
#       "type": "user"
#     }
#   }
# ]

# %%
import subprocess

#Get MLFLow UI through the Azure ML CLI v2 and convert to string
MLFLOW_TRACKING_URI = subprocess.run(["az", "ml", "workspace", "show", "--query", "mlflow_tracking_uri", "-o", "tsv"], stdout=subprocess.PIPE, text=True)
MLFLOW_TRACKING_URI = str(MLFLOW_TRACKING_URI.stdout).strip()

## Make sure the MLFLow URI looks something like this: 
## azureml://westus.api.azureml.ms/mlflow/v1.0/subscriptions/<Sub-ID>/resourceGroups/<RG>/providers/Microsoft.MachineLearningServices/workspaces/<WS>
print("MLFlow Tracking URI:", MLFLOW_TRACKING_URI)
# Out:
# WARNING: Command group 'ml workspace' is in preview and under development. Reference and support levels: https://aka.ms/CLI_refstatus
# MLFlow Tracking URI: azureml://westus.api.azureml.ms/mlflow/v1.0/subscriptions/95a911b6-47f7-4a8b-be9b-c1c2bf56579b/resourceGroups/osomorog/providers/Microsoft.MachineLearningServices/workspaces/mlflowworkspace

# %%
## Set the MLFLOW TRACKING URI
import mlflow
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# %% [markdown]
# # Run again with AzureML as Tracking Server

# %% [markdown]
# **NOTE**: This only works if the user has set an experiment in their code, if not it break. We need to be able to set a default experiment for the user with now experiment set. A default experiment flow will be avaible in future release

# %%
# Copyright (c) Microsoft. All rights reserved.
# Licensed under the MIT license.

import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import mlflow
import mlflow.sklearn

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

## User currently needs to add an experiment name. Should not be neccesary in a future relase
mlflow.set_experiment("test-abe")
########

with mlflow.start_run():
    X, y = load_diabetes(return_X_y=True)
    columns = ['age', 'gender', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    data = {
        "train": {"X": X_train, "y": y_train},
        "test": {"X": X_test, "y": y_test}}

    mlflow.log_metric("Training samples", len(data['train']['X']))
    mlflow.log_metric("Test samples", len(data['test']['X']))

    # Log the algorithm parameter alpha to the run
    mlflow.log_metric('alpha', 0.03)
    # Create, fit, and test the scikit-learn Ridge regression model
    regression_model = Ridge(alpha=0.03)
    regression_model.fit(data['train']['X'], data['train']['y'])
    preds = regression_model.predict(data['test']['X'])

    # Log mean squared error
    print('Mean Squared Error is', mean_squared_error(data['test']['y'], preds))
    mlflow.log_metric('mse', mean_squared_error(data['test']['y'], preds))

    # Save the model to the outputs directory for capture
    mlflow.sklearn.log_model(regression_model, "model")

    # Plot actuals vs predictions and save the plot within the run
    fig = plt.figure(1)
    idx = np.argsort(data['test']['y'])
    plt.plot(data['test']['y'][idx], preds[idx])
    fig.savefig("actuals_vs_predictions.png")
    mlflow.log_artifact("actuals_vs_predictions.png")
# Out:
# Mean Squared Error is 3424.900315896017

# %% [markdown]
# Check the Experiments page in AML to find the run details
